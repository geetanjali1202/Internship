# %% [markdown]
# # Web scraping - Assignment 4

# %% [markdown]
# Internship ID - DS2402
#
# Submitted by - Geetanjali Joshi

# %% [markdown]
# ## Q1 : Scrape the details of most viewed videos on YouTube from Wikipedia. Url
# ## = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos You need to find following details: A)
# ## Rank
# ## B) Name
# ## C) Artist
# ## D) Upload date
# ## E) Views

# %%
# !pip install bs4
# !pip install requests

# importing libraries 
import pandas as pd
import requests
from bs4 import BeautifulSoup
# Out:
# Requirement already satisfied: bs4 in ./anaconda3/lib/python3.10/site-packages (0.0.2)
# Requirement already satisfied: beautifulsoup4 in ./anaconda3/lib/python3.10/site-packages (from bs4) (4.11.1)
# Requirement already satisfied: soupsieve>1.2 in ./anaconda3/lib/python3.10/site-packages (from beautifulsoup4->bs4) (2.3.2.post1)
# Requirement already satisfied: requests in ./anaconda3/lib/python3.10/site-packages (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in ./anaconda3/lib/python3.10/site-packages (from requests) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./anaconda3/lib/python3.10/site-packages (from requests) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in ./anaconda3/lib/python3.10/site-packages (from requests) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./anaconda3/lib/python3.10/site-packages (from requests) (1.26.14)

# %%
# get the webpage 
page = requests.get('https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos')

# %%
page # 200 means we can scrape the data from the website
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.content)

# %%
soup = BeautifulSoup(page.content, 'html.parser')

# %%
table = soup.find('table',{'class': "type 1 table"})

# %%
table

# %%
url = 'https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos'

# %%
tables = pd.read_html(url)

# %%
len(tables) # number of tables on the webpage
# Out:
# 6

# %%
tables[0] # target table
# Out:
#                                          Video name  \
# 0                             "Baby Shark Dance"[7]
# 1                                   "Despacito"[10]
# 2                        "Johny Johny Yes Papa"[18]
# 3                                   "Bath Song"[19]
# 4                                "Shape of You"[20]
# 5                               "See You Again"[23]
# 6                           "Wheels on the Bus"[28]
# 7                 "Phonics Song with Two Words"[29]
# 8                                 "Uptown Funk"[30]
# 9                               "Gangnam Style"[31]
# 10  "Learning Colors – Colorful Eggs on a Farm"[36]
# 11                             "Dame Tu Cosita"[37]
# 12   "Masha and the Bear – Recipe for Disaster"[38]
# 13                                     "Axel F"[39]
# 14                                      "Sugar"[40]
# 15                        "Baa Baa Black Sheep"[41]
# 16                             "Counting Stars"[42]
# 17                             "Lakdi Ki Kathi"[43]
# 18                                       "Roar"[44]
# 19           "Waka Waka (This Time for Africa)"[45]
# 20                                      "Sorry"[46]
# 21                      "Shree Hanuman Chalisa"[47]
# 22          "Humpty the train on a fruits ride"[48]
# 23                          "Thinking Out Loud"[49]
# 24                                    "Perfect"[50]
# 25                                 "Dark Horse"[51]
# 26                                 "Let Her Go"[52]
# 27                                      "Faded"[53]
# 28                             "Girls Like You"[54]
# 29                                    "Lean On"[55]
# 30                              As of April 3, 2024
#
#                                              Uploader     Views (billions)  \
# 0         Pinkfong Baby Shark - Kids' Songs & Stories                14.32
# 1                                          Luis Fonsi                 8.41
# 2   LooLoo Kids - Nursery Rhymes and Children's Songs                 6.89
# 3                          Cocomelon - Nursery Rhymes                 6.66
# 4                                          Ed Sheeran                 6.23
# 5                                         Wiz Khalifa                 6.22
# 6                          Cocomelon - Nursery Rhymes                 6.01
# 7               ChuChu TV Nursery Rhymes & Kids Songs                 5.75
# 8                                         Mark Ronson                 5.18
# 9                                                 Psy                 5.10
# 10                                        Miroshka TV                 5.09
# 11                                      Ultra Records                 4.59
# 12                                         Get Movies                 4.57
# 13                                         Crazy Frog                 4.45
# 14                                           Maroon 5                 4.02
# 15                         Cocomelon - Nursery Rhymes                 4.01
# 16                                        OneRepublic                 4.00
# 17                                       Jingle Toons                 3.98
# 18                                         Katy Perry                 3.98
# 19                                            Shakira                 3.89
# 20                                      Justin Bieber                 3.78
# 21                              T-Series Bhakti Sagar                 3.77
# 22      Kiddiestv Hindi - Nursery Rhymes & Kids Songs                 3.76
# 23                                         Ed Sheeran                 3.75
# 24                                         Ed Sheeran                 3.70
# 25                                         Katy Perry                 3.70
# 26                                          Passenger                 3.64
# 27                                        Alan Walker                 3.60
# 28                                           Maroon 5                 3.58
# 29                               Major Lazer Official                 3.57
# 30                                As of April 3, 2024  As of April 3, 2024
#
#                    Date           Unnamed: 4
# 0         June 17, 2016                  [A]
# 1      January 12, 2017                  [B]
# 2       October 8, 2016                  NaN
# 3           May 2, 2018                  NaN
# 4      January 30, 2017                  [C]
# 5         April 6, 2015                  [D]
# 6          May 24, 2018                  NaN
# 7         March 6, 2014                  NaN
# 8     November 19, 2014                  NaN
# 9         July 15, 2012                  [E]
# 10    February 27, 2018                  NaN
# 11        April 5, 2018                  NaN
# 12     January 31, 2012                  NaN
# 13        June 16, 2009                  NaN
# 14     January 14, 2015                  NaN
# 15        June 25, 2018                  NaN
# 16         May 31, 2013                  NaN
# 17        June 14, 2018                  NaN
# 18    September 5, 2013                  NaN
# 19         June 4, 2010                  NaN
# 20     October 22, 2015                  NaN
# 21         May 10, 2011                  NaN
# 22     January 26, 2018                  NaN
# 23      October 7, 2014                  NaN
# 24     November 9, 2017                  NaN
# 25    February 20, 2014                  NaN
# 26        July 25, 2012                  NaN
# 27     December 3, 2015                  NaN
# 28         May 31, 2018                  NaN
# 29       March 22, 2015                  NaN
# 30  As of April 3, 2024  As of April 3, 2024

# %%
df = tables[0] # coverting table into a dataframe

# %%
df.head() # first 5 rows of the table
# Out:
#                    Video name  \
# 0       "Baby Shark Dance"[7]
# 1             "Despacito"[10]
# 2  "Johny Johny Yes Papa"[18]
# 3             "Bath Song"[19]
# 4          "Shape of You"[20]
#
#                                             Uploader Views (billions)  \
# 0        Pinkfong Baby Shark - Kids' Songs & Stories            14.32
# 1                                         Luis Fonsi             8.41
# 2  LooLoo Kids - Nursery Rhymes and Children's Songs             6.89
# 3                         Cocomelon - Nursery Rhymes             6.66
# 4                                         Ed Sheeran             6.23
#
#                Date Unnamed: 4
# 0     June 17, 2016        [A]
# 1  January 12, 2017        [B]
# 2   October 8, 2016        NaN
# 3       May 2, 2018        NaN
# 4  January 30, 2017        [C]

# %%
# renaming the columns 
df.rename(columns = {'Video name':'Name','Uploader': 'Artist','Views (billions)':'Views','Date':'Upload Date'}, inplace = True)

# %%
# droping unnamed columns 
df = df.drop(df.columns[df.columns.str.contains('Unnamed', case=False)], axis=1)

# %%
df.head()
# Out:
#                          Name  \
# 0       "Baby Shark Dance"[7]
# 1             "Despacito"[10]
# 2  "Johny Johny Yes Papa"[18]
# 3             "Bath Song"[19]
# 4          "Shape of You"[20]
#
#                                               Artist  Views       Upload Date
# 0        Pinkfong Baby Shark - Kids' Songs & Stories  14.32     June 17, 2016
# 1                                         Luis Fonsi   8.41  January 12, 2017
# 2  LooLoo Kids - Nursery Rhymes and Children's Songs   6.89   October 8, 2016
# 3                         Cocomelon - Nursery Rhymes   6.66       May 2, 2018
# 4                                         Ed Sheeran   6.23  January 30, 2017

# %%
df.columns
# Out:
# Index(['Name', 'Artist', 'Views', 'Upload Date'], dtype='object')

# %%
df.insert(0, 'Ranking', range(1, len(df) + 1))

# %%
# final dataframe with the required data
print('Most viewed videos from Youtube on wikipedia')
df
# Out:
# Most viewed videos from Youtube on wikipedia
#     Ranking                                             Name  \
# 0         1                            "Baby Shark Dance"[7]
# 1         2                                  "Despacito"[10]
# 2         3                       "Johny Johny Yes Papa"[18]
# 3         4                                  "Bath Song"[19]
# 4         5                               "Shape of You"[20]
# 5         6                              "See You Again"[23]
# 6         7                          "Wheels on the Bus"[28]
# 7         8                "Phonics Song with Two Words"[29]
# 8         9                                "Uptown Funk"[30]
# 9        10                              "Gangnam Style"[31]
# 10       11  "Learning Colors – Colorful Eggs on a Farm"[36]
# 11       12                             "Dame Tu Cosita"[37]
# 12       13   "Masha and the Bear – Recipe for Disaster"[38]
# 13       14                                     "Axel F"[39]
# 14       15                                      "Sugar"[40]
# 15       16                        "Baa Baa Black Sheep"[41]
# 16       17                             "Counting Stars"[42]
# 17       18                             "Lakdi Ki Kathi"[43]
# 18       19                                       "Roar"[44]
# 19       20           "Waka Waka (This Time for Africa)"[45]
# 20       21                                      "Sorry"[46]
# 21       22                      "Shree Hanuman Chalisa"[47]
# 22       23          "Humpty the train on a fruits ride"[48]
# 23       24                          "Thinking Out Loud"[49]
# 24       25                                    "Perfect"[50]
# 25       26                                 "Dark Horse"[51]
# 26       27                                 "Let Her Go"[52]
# 27       28                                      "Faded"[53]
# 28       29                             "Girls Like You"[54]
# 29       30                                    "Lean On"[55]
#
#                                                Artist  Views  \
# 0         Pinkfong Baby Shark - Kids' Songs & Stories  14.32
# 1                                          Luis Fonsi   8.41
# 2   LooLoo Kids - Nursery Rhymes and Children's Songs   6.89
# 3                          Cocomelon - Nursery Rhymes   6.66
# 4                                          Ed Sheeran   6.23
# 5                                         Wiz Khalifa   6.22
# 6                          Cocomelon - Nursery Rhymes   6.01
# 7               ChuChu TV Nursery Rhymes & Kids Songs   5.75
# 8                                         Mark Ronson   5.18
# 9                                                 Psy   5.10
# 10                                        Miroshka TV   5.09
# 11                                      Ultra Records   4.59
# 12                                         Get Movies   4.57
# 13                                         Crazy Frog   4.45
# 14                                           Maroon 5   4.02
# 15                         Cocomelon - Nursery Rhymes   4.01
# 16                                        OneRepublic   4.00
# 17                                       Jingle Toons   3.98
# 18                                         Katy Perry   3.98
# 19                                            Shakira   3.89
# 20                                      Justin Bieber   3.78
# 21                              T-Series Bhakti Sagar   3.77
# 22      Kiddiestv Hindi - Nursery Rhymes & Kids Songs   3.76
# 23                                         Ed Sheeran   3.75
# 24                                         Ed Sheeran   3.70
# 25                                         Katy Perry   3.70
# 26                                          Passenger   3.64
# 27                                        Alan Walker   3.60
# 28                                           Maroon 5   3.58
# 29                               Major Lazer Official   3.57
#
#           Upload Date
# 0       June 17, 2016
# 1    January 12, 2017
# 2     October 8, 2016
# 3         May 2, 2018
# 4    January 30, 2017
# 5       April 6, 2015
# 6        May 24, 2018
# 7       March 6, 2014
# 8   November 19, 2014
# 9       July 15, 2012
# 10  February 27, 2018
# 11      April 5, 2018
# 12   January 31, 2012
# 13      June 16, 2009
# 14   January 14, 2015
# 15      June 25, 2018
# 16       May 31, 2013
# 17      June 14, 2018
# 18  September 5, 2013
# 19       June 4, 2010
# 20   October 22, 2015
# 21       May 10, 2011
# 22   January 26, 2018
# 23    October 7, 2014
# 24   November 9, 2017
# 25  February 20, 2014
# 26      July 25, 2012
# 27   December 3, 2015
# 28       May 31, 2018
# 29     March 22, 2015

# %% [markdown]
# # 2. Scrape the details team India’s international fixtures from #bcci.tv.
# # Url = https://www.bcci.tv/.
# # You need to find following details:
# # A) Series
# # B) Place
# # C) Date
# # D) Time
# # Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
# get the webpage 
bcci = requests.get('https://www.bcci.tv/')

# %%
bcci
# Out:
# <Response [200]>

# %%
# !pip install selenium
import selenium
import pandas as pd
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')
from selenium.webdriver.common.by import By
import time
from selenium.common.exceptions import TimeoutException, NoSuchElementException
# Out:
# Requirement already satisfied: selenium in ./anaconda3/lib/python3.10/site-packages (4.19.0)
# Requirement already satisfied: typing_extensions>=4.9.0 in ./anaconda3/lib/python3.10/site-packages (from selenium) (4.10.0)
# Requirement already satisfied: urllib3[socks]<3,>=1.26 in ./anaconda3/lib/python3.10/site-packages (from selenium) (1.26.14)
# Requirement already satisfied: trio-websocket~=0.9 in ./anaconda3/lib/python3.10/site-packages (from selenium) (0.11.1)
# Requirement already satisfied: trio~=0.17 in ./anaconda3/lib/python3.10/site-packages (from selenium) (0.25.0)
# Requirement already satisfied: certifi>=2021.10.8 in ./anaconda3/lib/python3.10/site-packages (from selenium) (2023.5.7)
# Requirement already satisfied: idna in ./anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: exceptiongroup in ./anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in ./anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=23.2.0 in ./anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: outcome in ./anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in ./anaconda3/lib/python3.10/site-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in ./anaconda3/lib/python3.10/site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in ./anaconda3/lib/python3.10/site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in ./anaconda3/lib/python3.10/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
driver = webdriver.Chrome()
driver.get("https://www.bcci.tv/")

# %%
# press international tab toggle 
international_tab = driver.find_element(By.CLASS_NAME,"toggle")
international_tab.click()

# %%
# click on fixtures 
fixtures_tab = driver.find_element(By.XPATH,"/html/body/header/div[3]/div[2]/ul/div[1]/a[2]")
fixtures_tab.click()

# %%
match_series = []

series_tag = driver.find_elements(By.XPATH, '//h5[@class="match-tournament-name ng-binding"]')
for i in series_tag:
    ser=i.text
    match_series.append(ser)

# %%
match_series
# Out:
# ['INDIA WOMEN TOUR OF BANGLADESH T20 SERIES 2024',
#  'INDIA WOMEN TOUR OF BANGLADESH T20 SERIES 2024',
#  'ICC MENS T20 WORLD CUP 2024',
#  'ICC MENS T20 WORLD CUP 2024',
#  'ICC MENS T20 WORLD CUP 2024',
#  'ICC MENS T20 WORLD CUP 2024',
#  'INDIA TOUR OF ZIMBABWE 2024',
#  'INDIA TOUR OF ZIMBABWE 2024',
#  'INDIA TOUR OF ZIMBABWE 2024']

# %%
place = []

place_tag = driver.find_elements(By.XPATH, '//div[@class="match-place ng-scope"]')
for i in place_tag:
    pl=i.text
    place.append(pl)

# %%
place
# Out:
# ['Sylhet International Cricket Stadium, Sylhet',
#  'Nassau County International Cricket Stadium, New York',
#  'Nassau County International Cricket Stadium, New York',
#  'Nassau County International Cricket Stadium, New York',
#  'Central Broward Park & Broward County Stadium, Lauderhill, Florida',
#  'Harare Sports Club, Harare',
#  'Harare Sports Club, Harare',
#  'Harare Sports Club, Harare']

# %%
date = []

date_tag = driver.find_elements(By.XPATH, '//div[@class="match-dates ng-binding"]')
for i in date_tag:
    dt=i.text
    date.append(dt)

# %%
date
# Out:
# ['6 MAY, 2024',
#  '9 MAY, 2024',
#  '5 JUNE, 2024',
#  '9 JUNE, 2024',
#  '12 JUNE, 2024',
#  '15 JUNE, 2024',
#  '6 JULY, 2024',
#  '7 JULY, 2024',
#  '10 JULY, 2024']

# %%
time = []

time_tag = driver.find_elements(By.XPATH, '//div[@class="match-time no-margin ng-binding"]')
for i in time_tag:
    tim=i.text
    time.append(tim)

# %%
time
# Out:
# ['3:30 PM IST',
#  '3:30 PM IST',
#  '8:00 PM IST',
#  '8:00 PM IST',
#  '8:00 PM IST',
#  '8:00 PM IST',
#  '8:00 PM IST',
#  '8:00 PM IST',
#  '8:00 PM IST']

# %%
print(len(match_series),len(place),len(date),len(time))
# Out:
# 9 8 9 9

# %%
# turn into dataframe
international_fixtures=pd.DataFrame([])
international_fixtures['Series']=series[:8]
international_fixtures['Place']=place[:8]
international_fixtures['Date']=date[:8]
international_fixtures['Time']=time[:8]

# %%
# List of details of India's international fixtures from bcci.tv
international_fixtures
# Out:
#                                            Series  \
# 0  INDIA WOMEN TOUR OF BANGLADESH T20 SERIES 2024
# 1  INDIA WOMEN TOUR OF BANGLADESH T20 SERIES 2024
# 2                     ICC MENS T20 WORLD CUP 2024
# 3                     ICC MENS T20 WORLD CUP 2024
# 4                     ICC MENS T20 WORLD CUP 2024
# 5                     ICC MENS T20 WORLD CUP 2024
# 6                     INDIA TOUR OF ZIMBABWE 2024
# 7                     INDIA TOUR OF ZIMBABWE 2024
#
#                                                Place           Date  \
# 0       Sylhet International Cricket Stadium, Sylhet    6 MAY, 2024
# 1  Nassau County International Cricket Stadium, N...    9 MAY, 2024
# 2  Nassau County International Cricket Stadium, N...   5 JUNE, 2024
# 3  Nassau County International Cricket Stadium, N...   9 JUNE, 2024
# 4  Central Broward Park & Broward County Stadium,...  12 JUNE, 2024
# 5                         Harare Sports Club, Harare  15 JUNE, 2024
# 6                         Harare Sports Club, Harare   6 JULY, 2024
# 7                         Harare Sports Club, Harare   7 JULY, 2024
#
#           Time
# 0  3:30 PM IST
# 1  3:30 PM IST
# 2  8:00 PM IST
# 3  8:00 PM IST
# 4  8:00 PM IST
# 5  8:00 PM IST
# 6  8:00 PM IST
# 7  8:00 PM IST

# %% [markdown]
# # Q3. Scrape the details of State-wise GDP of India from statisticstime.com.
# # Url = http://statisticstimes.com/
# # You have to find following details: A) Rank
# # B) State
# # C) GSDP(21-22)- at current prices
# # D) GSDP(22-23)- at current prices
# # E) Share(21-22)
# # F) GDP($ billion)
# # Note: - From statisticstimes home page you have to reach to economy page through code.

# %%
driver = webdriver.Chrome()
driver.get("https://statisticstimes.com/")

# %%
# press economy tab 


economy_tab = driver.find_element(By.XPATH,"/html/body/div[2]/div[1]/div[2]/div[2]/button")
economy_tab.click()

# %%
ind = driver.find_element(By.XPATH,'/html/body/div[2]/div[1]/div[2]/div[2]/div/a[3]')       # Locating page foe top videos by xpath
ind.click()

# %%
gdp = driver.find_element(By.XPATH,'/html/body/div[2]/div[2]/div[2]/ul/li[1]/a')       # Locating page foe top videos by xpath
gdp.click()

# %%
#scraping the Rank
rank = []
rank_tag = driver.find_elements(By.XPATH,'//td[@class="data1"]')
for i in rank_tag:
    if i.text is None:
        rank.append("..")
    else:
        rank.append(i.text)

# %%
#scraping the Rank
state = []
state_tag = driver.find_elements(By.XPATH,'//td[@class="name"]')
for i in state_tag:
    if i.text is None:
        state.append("..")
    else:
        state.append(i.text)

# %%
# share of states
share = []

shr =driver.find_elements(By.XPATH, "//*[@id='table_id']/tbody/tr/td[6]")
for i in shr:
    if i.text is None :
        share.append("..") 
    else:
        share.append(i.text)

# %%
# GSDP(22-23)- at current prices¶
gsdp_2223 = []

gsdp_2 =driver.find_elements(By.XPATH, "//*[@id='table_id']/tbody/tr/td[4]")
for i in gsdp_2:
    if i.text is None :
        gsdp_2223.append("..") 
    else:
        gsdp_2223.append(i.text)

# %%
# GSDP(21-22)- at current prices¶
gsdp_2122 = []

gsdp_1 =driver.find_elements(By.XPATH, "//*[@id='table_id']/tbody/tr/td[5]")
for i in gsdp_1:
    if i.text is None :
        gsdp_2122.append("..") 
    else:
        gsdp_2122.append(i.text)

# %%
# gdp in billion of states
gdp = []

gdp_tag =driver.find_elements(By.XPATH, "//*[@id='table_id']/tbody/tr/td[7]")
for i in gdp_tag:
    if i.text is None :
        gdp.append("..") 
    else:
        gdp.append(i.text)

# %%
print(len(rank),len(state),len(gdp),len(gsdp_2122),len(gsdp_2223))
# Out:
# 68 68 33 33 33

# %%
# turn into dataframe
state_details =pd.DataFrame([])
state_details['Rank']=rank[:33]
state_details['State']=state[:33]
state_details['GDP']=gdp[:33]
state_details['GSDP(21-22) : current price']=gsdp_2122[:33]
state_details['GSDP(22-23) : current price']=gsdp_2223[:33]

# %%
state_details
# Out:
#    Rank                      State      GDP GSDP(21-22) : current price  \
# 0     1                Maharashtra  414.928                   3,108,022
# 1     2                 Tamil Nadu  276.522                   2,071,286
# 2     3                  Karnataka  264.080                   1,978,094
# 3     4              Uttar Pradesh  263.747                   1,975,595
# 4     5                    Gujarat  257.484                   1,928,683
# 5     6                West Bengal  177.456                   1,329,238
# 6     7                  Rajasthan  159.334                   1,193,489
# 7     8             Andhra Pradesh  153.324                   1,148,471
# 8     9                  Telangana  150.084                   1,124,204
# 9    10             Madhya Pradesh  145.913                   1,092,964
# 10   11                     Kerala  124.764                     934,542
# 11   12                      Delhi  117.660                     881,336
# 12   13                    Haryana  116.001                     868,905
# 13   14                     Odisha   88.497                     662,886
# 14   15                      Bihar   86.817                     650,302
# 15   16                     Punjab   82.397                     617,192
# 16   17                      Assam   54.930                     411,454
# 17   18               Chhattisgarh   54.806                     410,525
# 18   19                  Jharkhand   47.909                     358,863
# 19   20                Uttarakhand   35.664                     267,143
# 20   21            Jammu & Kashmir   25.813                     193,352
# 21   22           Himachal Pradesh   22.984                     172,162
# 22   23                        Goa   11.250                      84,266
# 23   24                    Tripura    8.351                      62,550
# 24   25                 Chandigarh    6.154                      46,096
# 25   26                 Puducherry    5.849                      43,810
# 26   27                  Meghalaya    5.178                      38,785
# 27   28                     Sikkim    5.014                      37,557
# 28   29                    Manipur    4.885                      36,594
# 29   30          Arunachal Pradesh    4.643                      34,775
# 30   31                   Nagaland    4.144                      31,038
# 31   32                    Mizoram    3.715                      27,824
# 32   33  Andaman & Nicobar Islands    1.385                      10,371
#
#    GSDP(22-23) : current price
# 0                            -
# 1                    2,364,514
# 2                    2,269,995
# 3                    2,258,040
# 4                    2,230,609
# 5                    1,531,758
# 6                    1,365,849
# 7                    1,303,524
# 8                    1,308,034
# 9                    1,246,471
# 10                   1,046,188
# 11                   1,014,688
# 12                     984,055
# 13                     753,177
# 14                     751,396
# 15                     676,164
# 16                     493,167
# 17                     464,399
# 18                     393,722
# 19                     303,781
# 20                     224,226
# 21                     191,728
# 22                      93,672
# 23                      72,636
# 24                      54,285
# 25                      49,643
# 26                      42,697
# 27                      42,756
# 28                           -
# 29                      39,630
# 30                      35,643
# 31                           -
# 32                           -

# %% [markdown]
# # 4. Scrape the details of trending repositories on Github.com.
# # Url = https://github.com/
# # You have to find the following details:
# # A) Repository title
# # B) Repository description
# # C) Contributors count
# # D) Language used
# # Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver = webdriver.Chrome()
driver.get("https://github.com/")

# %%
# press open source 
open_source = driver.find_element(By.XPATH,'//li[@class="HeaderMenu-item position-relative flex-wrap flex-justify-between flex-items-center d-block d-lg-flex flex-lg-nowrap flex-lg-items-center js-details-container js-header-menu-item"][3]')
open_source.click()

# %%
# press open source 
trending = driver.find_element(By.XPATH,'/html/body/div[1]/div[1]/header/div/div[2]/div/nav/ul/li[3]/div/div[3]/ul/li[2]/a')
trending.click()

# %%
#scraping repository title
repository_title = []
repository_tag = driver.find_elements(By.XPATH,'//h2[@class="h3 lh-condensed"]')
for i in repository_tag:
    if i.text is None:
        repository_title .append("..")
    else:
        repository_title .append(i.text)

# %%
# Out:
# ['wandb / openui',
#  'massgravel / Microsoft-Activation-Scripts',
#  'HVision-NKU / StoryDiffusion',
#  'reorproject / reor',
#  'rasbt / LLMs-from-scratch',
#  'dev-xo / remix-saas',
#  'codecrafters-io / build-your-own-x',
#  'abi / secret-llama',
#  'Stirling-Tools / Stirling-PDF',
#  'xM4ddy / OFGB',
#  'fastfetch-cli / fastfetch',
#  'KindXiaoming / pykan',
#  'karpathy / llm.c',
#  'bepass-org / oblivion-desktop',
#  'Ryujinx / Ryujinx',
#  'systemdesign42 / system-design',
#  'lencx / ChatGPT',
#  'lmstudio-ai / lms',
#  'dockur / windows',
#  'novuhq / novu',
#  'solana-labs / solana',
#  'VinciGit00 / Scrapegraph-ai',
#  'plandex-ai / plandex',
#  'pagefaultgames / pokerogue',
#  'suyu-emu / suyu']

# %%
#scraping repository description
repository_desc = []
desc_tag = driver.find_elements(By.XPATH,'//p[@class="col-9 color-fg-muted my-1 pr-4"]')
for i in desc_tag:
    if i.text is None:
        repository_desc.append("..")
    else:
        repository_desc.append(i.text)

# %%
#scraping contributors count
contributors = []
contibutors_tag = driver.find_elements(By.XPATH,'//span[@class="d-inline-block mr-3"]')
for i in contibutors_tag:
    if i.text is None:
        contributors.append("..")
    else:
        contributors.append(i.text)

# %%
contributors
# Out:
# ['Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by',
#  'Built by']

# %%
#scraping language used
language = []
language_tag = driver.find_elements(By.XPATH,'//span[@class="d-inline-block ml-0 mr-3"]')
for i in language_tag:
    if i.text is None:
        language.append("..")
    else:
        language.append(i.text)

# %%
print(len(repository_title),len(repository_desc),len(contributors),len(language))
# Out:
# 25 24 25 23

# %%
# turn into dataframe
github =pd.DataFrame([])
github['Repository Title']=repository_title[:23]
github['Repository Description']=repository_desc[:23]
github['Contributors']=contributors[:23]
github['Language']=language[:23]

# %%
github
# Out:
#                              Repository Title  \
# 0                              wandb / openui
# 1   massgravel / Microsoft-Activation-Scripts
# 2                HVision-NKU / StoryDiffusion
# 3                          reorproject / reor
# 4                   rasbt / LLMs-from-scratch
# 5                         dev-xo / remix-saas
# 6          codecrafters-io / build-your-own-x
# 7                          abi / secret-llama
# 8               Stirling-Tools / Stirling-PDF
# 9                               xM4ddy / OFGB
# 10                  fastfetch-cli / fastfetch
# 11                       KindXiaoming / pykan
# 12                           karpathy / llm.c
# 13              bepass-org / oblivion-desktop
# 14                          Ryujinx / Ryujinx
# 15             systemdesign42 / system-design
# 16                            lencx / ChatGPT
# 17                          lmstudio-ai / lms
# 18                           dockur / windows
# 19                              novuhq / novu
# 20                       solana-labs / solana
# 21                VinciGit00 / Scrapegraph-ai
# 22                       plandex-ai / plandex
#
#                                Repository Description Contributors  \
# 0   OpenUI let's you describe UI using your imagin...     Built by
# 1   A Windows and Office activator using HWID / Oh...     Built by
# 2                                 Create Magic Story!     Built by
# 3   Private & offline AI personal knowledge manage...     Built by
# 4   Implementing a ChatGPT-like LLM from scratch, ...     Built by
# 5   A Lightweight, Production-Ready Remix Stack fo...     Built by
# 6   Master programming by recreating your favorite...     Built by
# 7   Fully private LLM chatbot that runs entirely w...     Built by
# 8   #1 Locally hosted web application that allows ...     Built by
# 9   GUI Tool To Removes Ads From Various Places Ar...     Built by
# 10  Like neofetch, but much faster because written...     Built by
# 11                         Kolmogorov Arnold Networks     Built by
# 12                 LLM training in simple, raw C/CUDA     Built by
# 13             unofficial desktop version of oblivion     Built by
# 14  Experimental Nintendo Switch Emulator written ...     Built by
# 15        A resource to help you learn system design.     Built by
# 16  🔮 ChatGPT Desktop Application (Mac, Windows an...     Built by
# 17                         LM Studio in your terminal     Built by
# 18                     Windows in a Docker container.     Built by
# 19  🔥 The open-source notification infrastructure ...     Built by
# 20  Web-Scale Blockchain for fast, secure, scalabl...     Built by
# 21                         Python scraper based on AI     Built by
# 22  An AI coding engine for building complex, real...     Built by
#
#             Language
# 0         TypeScript
# 1          Batchfile
# 2   Jupyter Notebook
# 3         TypeScript
# 4   Jupyter Notebook
# 5         TypeScript
# 6         TypeScript
# 7               Java
# 8                 C#
# 9                  C
# 10  Jupyter Notebook
# 11              Cuda
# 12        TypeScript
# 13                C#
# 14              Rust
# 15        TypeScript
# 16             Shell
# 17        TypeScript
# 18              Rust
# 19            Python
# 20                Go
# 21        TypeScript
# 22               C++

# %% [markdown]
# # 5. Scrape the details of top 100 songs on billiboard.com. Url = https:/www.billboard.com/ You have to find the following details:
# # A) Song name
# # B) Artist name
# # C) Last week rank
# # D) Peak rank
# # E) Weeks on board
# # Note: - From the home page you have to click on the charts option then hot 100-page link through code.

# %%
driver = webdriver.Chrome()
driver.get("https://www.billboard.com/")

# %%
billboard100 = driver.find_element(By.XPATH,'//a[@class="c-link  lrv-a-unstyle-link lrv-u-color-brand-primary:hover lrv-a-hover-effect lrv-u-whitespace-nowrap lrv-u-color-grey-dark"]')       # Locating page foe top videos by xpath
billboard100.click()

# %%
song_name =[]
artist=[]
last_week_rank=[]
peak_rank=[]
weeks_on_board=[]

# %%
#scraping the song name
song_names=driver.find_elements(By.XPATH,'//ul[@class="lrv-a-unstyle-list lrv-u-flex lrv-u-height-100p lrv-u-flex-direction-column@mobile-max"]/li/h3')
for i in song_names:
    if i.text is None :
        song_name.append("--") 
    else:
        song_name.append(i.text)

# %%
#scraping the artist
artist_names=driver.find_elements(By.XPATH,'//span[@class="c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only"]')
for i in artist_names:
    if i.text is None :
        artist.append("--") 
    else:
        artist.append(i.text)

# %%
#scraping the last week's rank
lrank=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max lrv-u-flex-grow-1"][1]')
for i in lrank:
    if i.text is None :
        last_week_rank.append("--") 
    else:
        last_week_rank.append(i.text)

# %%
#scraping the peak rank
prank=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light lrv-u-flex-grow-1"][2]')
for i in prank:
    if i.text is None :
        peak_rank.append("--") 
    else:
        peak_rank.append(i.text)

# %%
#scraping the weeks on board
wboard=driver.find_elements(By.XPATH,'//li[@class="o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max lrv-u-flex-grow-1"][2]')
for i in wboard:
    if i.text is None :
        weeks_on_board.append("--") 
    else:
        weeks_on_board.append(i.text)

# %%
print(len(song_name),len(artist),len(last_week_rank),len(peak_rank),len(weeks_on_board))
# Out:
# 104 99 100 100 100

# %%
# turn into dataframe
billboard =pd.DataFrame([])
billboard['Song Name']=song_name[:99]
billboard['Artist']=artist[:99]
billboard['Last Weeks rank']=last_week_rank[:99]
billboard['Peak Rank']=peak_rank[:99]
billboard['Weeks on board']=weeks_on_board[:99]

# %%
billboard
# Out:
#                       Song Name             Artist Last Weeks rank Peak Rank  \
# 0                     Fortnight       Taylor Swift               -         1
# 1                     Fortnight       Taylor Swift               -         2
# 2                     Fortnight       Taylor Swift               -         3
# 3                      Down Bad       Taylor Swift               -         4
# 4                     Fortnight       Taylor Swift               -         5
# ..                          ...                ...             ...       ...
# 94                           23        $uicideBoy$              94        94
# 95              Tucson Too Late     Tucker Wetmore               -        96
# 96              Halfway To Hell      Morgan Wallen              84        77
# 97  Praise Jah In The Moonlight           310babii              89        24
# 98                      Feel It  Justin Timberlake              82        53
#
#    Weeks on board
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# ..            ...
# 94              2
# 95              1
# 96              5
# 97             13
# 98             19
#
# [99 rows x 5 columns]

# %% [markdown]
# # 6. Scrape the details of Highest selling novels.
# # A) Book name
# # B) Author name
# # C) Volumes sold
# # D) Publisher
# # E) Genre
# # Url - https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare

# %%
driver = webdriver.Chrome()
driver.get("https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare")

# %%
#scraping the book name
book_name = []
bk=driver.find_elements(By.XPATH,'//td[@class="left"][2]')
for i in bk:
    if i.text is None:
        book_name.append("..") 
    else:
        book_name.append(i.text)

# %%
#scraping the author name
author_name = []
am=driver.find_elements(By.XPATH,'//td[@class="left"][3]')
for i in am:
    if i.text is None:
        author_name.append("..") 
    else:
        author_name.append(i.text)

# %%
#scraping the volume sold
volume_sold = []
vs=driver.find_elements(By.XPATH,'//td[@class="left"][4]')
for i in vs:
    if i.text is None:
        volume_sold.append("..") 
    else:
        volume_sold.append(i.text)

# %%
#scraping the publisher
publisher = []
pb=driver.find_elements(By.XPATH,'//td[@class="left"][5]')
for i in pb:
    if i.text is None:
        publisher.append("..") 
    else:
        publisher.append(i.text)

# %%
#scraping the publisher
Genre= []
gn=driver.find_elements(By.XPATH,'//td[@class="last left"]')
for i in gn:
    if i.text is None:
        Genre.append("..") 
    else:
        Genre.append(i.text)

# %%
print(len(book_name),len(author_name),len(volume_sold),len(publisher),len(Genre))
# Out:
# 100 100 100 100 100

# %%
# turn into dataframe
Novels =pd.DataFrame([])
Novels['Novel']=book_name
Novels['Author']=author_name
Novels['Volume Sold']=volume_sold
Novels['Publisher']=publisher
Novels['Genre']=Genre

# %%
Novels
# Out:
#                                                 Novel            Author  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
#    Volume Sold        Publisher                        Genre
# 0    5,094,805       Transworld  Crime, Thriller & Adventure
# 1    4,475,152       Bloomsbury           Children's Fiction
# 2    4,200,654       Bloomsbury           Children's Fiction
# 3    4,179,479       Bloomsbury           Children's Fiction
# 4    3,758,936     Random House              Romance & Sagas
# ..         ...              ...                          ...
# 95     807,311     Random House   General & Literary Fiction
# 96     794,201          Penguin        Food & Drink: General
# 97     792,187  Scholastic Ltd.          Young Adult Fiction
# 98     791,507            Orion           Biography: General
# 99     791,095          Penguin        Food & Drink: General
#
# [100 rows x 5 columns]

# %% [markdown]
# # 7. Scrape the details most watched tv series of all time from imdb.com.
# # Url = https://www.imdb.com/list/ls095964455/ You have to find the following details:
# # A) Name
# # B) Year span
# # C) Genre
# # D) Run time
# # E) Ratings
# # F) Votes

# %%
driver = webdriver.Chrome()
driver.get("https://www.imdb.com/list/ls512407256/")

# %%
#scraping the name
name = []
tvnames=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/a')
for i in tvnames:
    if i.text is None:
        name.append("..") 
    else:
        name.append(i.text)

# %%
#scraping genre
genre= []
g=driver.find_elements(By.XPATH,'//span[@class="genre"]')
for i in g:
    if i.text is None:
        genre.append("..") 
    else:
        genre.append(i.text)

# %%
#scraping year span
year_span= []
yr=driver.find_elements(By.XPATH,'//h3[@class="lister-item-header"]/span[2]')
for i in yr:
    if i.text is None:
        year_span.append("..") 
    else:
        year_span.append(i.text)

# %%
#scraping runtime
runtime= []
run=driver.find_elements(By.XPATH,'//span[@class="runtime"]')
for i in run:
    if i.text is None:
        runtime.append("..") 
    else:
        runtime.append(i.text)

# %%
#scraping year ratings
ratings= []
rt=driver.find_elements(By.XPATH,'//div[@class="ipl-rating-star small"]')
for i in rt:
    if i.text is None:
        ratings.append("..") 
    else:
        ratings.append(i.text)

# %%
#scraping views
votes= []
vote=driver.find_elements(By.XPATH,'//p[@class="text-muted text-small"][3]')
for i in vote:
    if i.text is None:
        votes.append("..") 
    else:
        votes.append(i.text)

# %%
print(len(name),len(genre),len(year_span),len(runtime),len(ratings),len(votes))
# Out:
# 100 100 100 100 100 100

# %%
# turn into dataframe
imdb =pd.DataFrame([])
imdb['Name']=name
imdb['Genre']=genre
imdb['Year Span']=year_span
imdb['Runtime']=runtime
imdb['Ratings']=ratings
imdb['Votes']=votes

# %%
imdb
# Out:
#                     Name                     Genre    Year Span Runtime  \
# 0        Game of Thrones  Action, Adventure, Drama  (2011–2019)  60 min
# 1        Stranger Things    Drama, Fantasy, Horror  (2016–2025)  60 min
# 2       The Walking Dead   Drama, Horror, Thriller  (2010–2022)  45 min
# 3         13 Reasons Why  Drama, Mystery, Thriller  (2017–2020)  60 min
# 4                The 100    Drama, Mystery, Sci-Fi  (2014–2020)  43 min
# ..                   ...                       ...          ...     ...
# 95        True Detective     Crime, Drama, Mystery     (2014– )  60 min
# 96             Teen Wolf    Action, Drama, Fantasy  (2011–2017)  41 min
# 97                The OA   Drama, Fantasy, Mystery  (2016–2019)  60 min
# 98          The Simpsons         Animation, Comedy     (1989– )  22 min
# 99  Desperate Housewives    Comedy, Drama, Mystery  (2004–2012)  45 min
#
#    Ratings             Votes
# 0      9.2  Votes: 2,287,506
# 1      8.7  Votes: 1,338,376
# 2      8.1  Votes: 1,083,328
# 3      7.5    Votes: 315,777
# 4      7.6    Votes: 276,531
# ..     ...               ...
# 95     8.9    Votes: 657,307
# 96     7.7    Votes: 163,393
# 97     7.8    Votes: 115,982
# 98     8.7    Votes: 436,316
# 99     7.6    Votes: 139,890
#
# [100 rows x 6 columns]

# %% [markdown]
# # 8. Details of Datasets from UCI machine learning repositories.
# # Url = https://archive.ics.uci.edu/ You have to find the following details:
# # A) Dataset name
# # B) Data type
# # C) Task
# # D) Attribute type
# # E) No of instances
# # F) No of attribute G) Year
# # Note: - from the home page you have to go to the Show All Dataset page through code.

# %%
driver = webdriver.Chrome()
driver.get("https://archive.ics.uci.edu/")

# %%
# view all datasets 
alldatasets = driver.find_element(By.XPATH,'//a[@class="btn-primary btn"]')
alldatasets.click()

# %%
#scraping the dataset name
dataset = []
dnames=driver.find_elements(By.XPATH,'//h2[@class="truncate text-primary"]')
for i in dnames:
    if i.text is None:
        dataset.append("..") 
    else:
        dataset.append(i.text)

# %%
#scraping the datatype
data_type = []
dtype=driver.find_elements(By.XPATH,'//div[@class="col-span-3 flex items-center gap-2"][2]')
for i in dtype:
    if i.text is None:
        data_type.append("..") 
    else:
        data_type.append(i.text)

# %%
data_type
# Out:
# ['Tabular',
#  'Multivariate',
#  'Multivariate',
#  'Multivariate',
#  'Multivariate',
#  'Multivariate',
#  'Multivariate',
#  'Tabular',
#  'Multivariate',
#  'Multivariate, Time-Series']

# %%
#scraping the tasks
task = []
t=driver.find_elements(By.XPATH,'//div[@class="col-span-3 flex items-center gap-2"][1]')
for i in t:
    if i.text is None:
        task.append("..") 
    else:
        task.append(i.text)

# %%
#scraping the tasks
instances = []
inst=driver.find_elements(By.XPATH,'//div[@class="col-span-3 flex items-center gap-2"][3]')
for i in inst:
    if i.text is None:
        instances.append("..") 
    else:
        instances.append(i.text)

# %%
# Out:
# ['Classification',
#  'Classification',
#  'Classification',
#  'Classification',
#  'Classification',
#  'Classification',
#  'Classification',
#  'Classification',
#  'Classification, Regression',
#  'Classification']

# %%
#scraping the features/attributes
feature_count = []
feat=driver.find_elements(By.XPATH,'//div[@class="col-span-3 flex items-center gap-2"][4]')
for i in feat:
    if i.text is None:
        feature_count.append("..") 
    else:
        feature_count.append(i.text)

# %%
#scraping the features/attributes
feature_type = []
ftype=driver.find_elements(By.XPATH,'//tbody[@class="border"]/tr/td[2]')
for i in ftype:
    if i.text is None:
        feature_type.append("..") 
    else:
        feature_type.append(i.text)

# %%
feature_type
# Out:
# ['Real',
#  'Categorical, Integer, Real',
#  'Integer, Real',
#  'Real',
#  'Categorical, Integer',
#  'Real',
#  'Real, Integer',
#  'Integer, Real',
#  'Real',
#  'Categorical, Integer']

# %%
#scraping the date
dates = []
d=driver.find_elements(By.XPATH,'//tbody[@class="border"]/tr/td[3]')
for i in d:
    if i.text is None:
        dates.append("--") 
    else:
        dates.append(i.text)

# %%
years = [dates.split('/')[2] for data in dates]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[340], line 1
# ----> 1 years = [dates.split('/')[2] for data in dates]
#
# Cell In[340], line 1, in <listcomp>(.0)
# ----> 1 years = [dates.split('/')[2] for data in dates]
#
# AttributeError: 'list' object has no attribute 'split'

# %%
print(len(dataset),len(data_type),len(task),len(instances),len(feature_count),len(feature_type),len(dates))
# Out:
# 10 10 10 10 10 10 10

# %%
# turn into dataframe
ucidata =pd.DataFrame([])
ucidata['Dataset title']=dataset
ucidata['Data Type']=data_type
ucidata['Task']=task
ucidata['No. of instances']=instances
ucidata['Attribute numbers']=feature_count
ucidata['Attribute types']=feature_type
ucidata['Date']=dates

# %%
ucidata
# Out:
#                           Dataset title                  Data Type  \
# 0                                  Iris                    Tabular
# 1                         Heart Disease               Multivariate
# 2                              Dry Bean               Multivariate
# 3            Rice (Cammeo and Osmancik)               Multivariate
# 4                                 Adult               Multivariate
# 5  Breast Cancer Wisconsin (Diagnostic)               Multivariate
# 6                                Raisin               Multivariate
# 7                                  Wine                    Tabular
# 8                          Wine Quality               Multivariate
# 9                              Diabetes  Multivariate, Time-Series
#
#                          Task  No. of instances Attribute numbers  \
# 0              Classification     150 Instances        4 Features
# 1              Classification     303 Instances       13 Features
# 2              Classification  13.61K Instances       16 Features
# 3              Classification   3.81K Instances        7 Features
# 4              Classification  48.84K Instances       14 Features
# 5              Classification     569 Instances       30 Features
# 6              Classification     900 Instances        8 Features
# 7              Classification     178 Instances       13 Features
# 8  Classification, Regression    4.9K Instances       12 Features
# 9              Classification       1 Instances       20 Features
#
#               Attribute types       Date
# 0                        Real   7/1/1988
# 1  Categorical, Integer, Real   7/1/1988
# 2               Integer, Real  9/14/2020
# 3                        Real  10/6/2019
# 4        Categorical, Integer   5/1/1996
# 5                        Real  11/1/1995
# 6               Real, Integer  8/14/2023
# 7               Integer, Real   7/1/1991
# 8                        Real  10/7/2009
# 9        Categorical, Integer        N/A
